# %%
#generates 3d histograms for the data
import numpy as np
import pprint as pp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pprint
import pandas as pd

# %matplotlib notebook

from matplotlib import style
style.use('ggplot')

#SET 1 - NO REGIONS############################################################################################################
col1 = np.array(np.loadtxt(r"ConfidenceData\NewGeneratedDataNoRegionsConfidenceInformation_y_confidence_labels.txt"))
col2 = np.array(np.loadtxt(r"ConfidenceData\NewGeneratedDataNoRegionsConfidenceInformation_y_pred_real.txt"))
col3to5 = np.loadtxt(r"ConfidenceData\NewGeneratedDataNoRegionsConfidenceInformation_y_confidence.txt", delimiter=" ")
col3 = np.array(col3to5[:,0])
col4 = np.array(col3to5[:,1])
col5 = np.array(col3to5[:,2])

df = pd.DataFrame({'SpeedAlertsId': col1, 'PredictedLabel': col2, 'A1MSouthConfidence': col3, 'A1MNorthConfidence': col4, 'A6055Confidence': col5})

#A1MSouth
condition_a = df['PredictedLabel'] == 0
condition_b = df['A1MSouthConfidence'] <= 0.95
conditon_c = df['A1MSouthConfidence'] >= 0.5

A1MSouthConfidencesSet = df[condition_a]
A1MSouthConfidences = A1MSouthConfidencesSet["A1MSouthConfidence"]
#print(A1MSouthConfidences)

#A1MNorth
condition_d = df['PredictedLabel'] == 1
condition_e = df['A1MNorthConfidence'] <= 0.95
condition_f = df['A1MNorthConfidence'] >= 0.5

A1MNorthConfidencesSet = df[condition_d]
A1MNorthConfidences = A1MNorthConfidencesSet["A1MNorthConfidence"]
#print(A1MNorthConfidences)

#A6055
condition_g = df['PredictedLabel'] == 2
condition_h = df['A6055Confidence'] <= 0.95
condition_i = df['A6055Confidence'] >= 0.5

A6055ConfidencesSet = df[condition_g]
A6055Confidences = A6055ConfidencesSet["A6055Confidence"]
#print(A6055Confidences)

fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

fig1, ax1 = plt.subplots()

HistA1MS, bins, patches = ax1.hist(A1MSouthConfidences, bins=100, label='hst')
HistA1MN, bins2, patches2 = ax1.hist(A1MNorthConfidences, bins=100, label='hst2')
HistA6055, bins3, patches3 = ax1.hist(A6055Confidences, bins=100, label='hst3')

binsize = 100

#A1MSouthConfidences
xpos = list(range(0, binsize))
ypos = list([2] * len(HistA1MS))
zpos = [0] * len(HistA1MS)
dx = list([0.8] * binsize)
dy = list([0.1] * binsize)
dz = HistA1MS

#A1MNorthConfidences
xpos2 = list(range(0, binsize))
ypos2 = list([1] * len(HistA1MN))
zpos2 = [0] * len(HistA1MN)
dx2 = list([0.8] * binsize)
dy2 = list([0.1] * binsize)
dz2 = HistA1MN

#A6055Confidences
xpos3 = list(range(0, binsize))
ypos3 = list([0] * len(HistA6055))
zpos3 = [0] * len(HistA6055)
dx3 = list([0.8] * binsize)
dy3 = list([0.1] * binsize)
dz3 = HistA6055


#SET 2 - REGIONS ##########################################################################################
col1 = np.array(np.loadtxt(r"ConfidenceData\GeneratedDataRegionsConfidenceInformation_y_confidence_labels.txt"))
col2 = np.array(np.loadtxt(r"ConfidenceData\GeneratedDataRegionsConfidenceInformationy_y_pred.txt"))
col3to5 = np.loadtxt(r"ConfidenceData\GeneratedDataRegionsConfidenceInformationy_confidence.txt", delimiter=" ")
col3 = np.array(col3to5[:,0])
col4 = np.array(col3to5[:,1])
col5 = np.array(col3to5[:,2])

df2 = pd.DataFrame({'SpeedAlertsId': col1, 'PredictedLabel': col2, 'A1MSouthConfidence': col3, 'A1MNorthConfidence': col4, 'A6055Confidence': col5})
print(df2)

#A1MSouth
condition_a = df2['PredictedLabel'] == 0
condition_b = df2['A1MSouthConfidence'] <= 0.95
conditon_c = df2['A1MSouthConfidence'] >= 0.5

A1MSouthConfidencesSet2 = df2[condition_a]
A1MSouthConfidences2 = A1MSouthConfidencesSet2["A1MSouthConfidence"]
#print(A1MSouthConfidences)

#A1MNorth
condition_d = df2['PredictedLabel'] == 1
condition_e = df2['A1MNorthConfidence'] <= 0.95
condition_f = df2['A1MNorthConfidence'] >= 0.5

A1MNorthConfidencesSet2 = df2[condition_d]
A1MNorthConfidences2 = A1MNorthConfidencesSet2["A1MNorthConfidence"]
#print(A1MNorthConfidences)

#A6055
condition_g = df2['PredictedLabel'] == 2
condition_h = df2['A6055Confidence'] <= 0.95
condition_i = df2['A6055Confidence'] >= 0.5

A6055ConfidencesSet2 = df2[condition_g]
A6055Confidences2 = A6055ConfidencesSet2["A6055Confidence"]
#print(A6055Confidences)

fig2, ax2 = plt.subplots()

HistA1MS2, bins2, patches2 = ax2.hist(A1MSouthConfidences2, bins=100, label='hst')
HistA1MN2, bins22, patches22 = ax2.hist(A1MNorthConfidences2, bins=100, label='hst2')
HistA60552, bins32, patches32 = ax2.hist(A6055Confidences2, bins=100, label='hst3')

#A6055Confidences
xpos4 = list(range(0, binsize))
ypos4 = list([6] * len(HistA1MS2))
zpos4 = [0] * len(HistA1MS2)
dx4 = list([0.8] * binsize)
dy4 = list([0.1] * binsize)
dz4 = HistA1MS2

#A1MNorthConfidences
xpos5 = list(range(0, binsize))
ypos5 = list([5] * len(HistA1MN2))
zpos5 = [0] * len(HistA1MN2)
dx5 = list([0.8] * binsize)
dy5= list([0.1] * binsize)
dz5 = HistA1MN2

#A1MSouthConfidences
xpos6 = list(range(0, binsize))
ypos6 = list([4] * len(HistA60552))
zpos6 = [0] * len(HistA60552)
dx6 = list([0.8] * binsize)
dy6 = list([0.1] * binsize)
dz6 = HistA60552


# PLOT##################################################################################################################
ax3d = fig.add_subplot(111, projection='3d')

ax3d.bar3d(xpos3, ypos3, zpos3, dx3, dy3, dz3, color="green", label='A1M North No Regions')
ax3d.bar3d(xpos2, ypos2, zpos2, dx2, dy2, dz2, color="red", label='A1M South No Regions')
ax3d.bar3d(xpos, ypos, zpos, dx, dy, dz, color="blue", label='A6055 No Regions')


ax3d.bar3d(xpos6, ypos6, zpos6, dx6, dy6, dz6, color="green", label='A1M North With Regions')
ax3d.bar3d(xpos5, ypos5, zpos5, dx5, dy5, dz5, color="red", label='A1M South With Regions')
ax3d.bar3d(xpos4, ypos4, zpos4, dx4, dy4, dz4, color="blue", label='A6055 with Regions')

ax3d.set_xlabel('confidence (probability)')
ax3d.set_ylabel('y axis')
ax3d.set_zlabel('count')

#change for each dataset
#plt.savefig("SpeedingClassificationConfidencesNewGeneratedDataNoRegions26-11-20at2149.png")
# Out:
# <img src="data:image/png;base64,..." width="1125.833288596738">
# <img src="data:image/png;base64,..." width="639.999974568686">
#        SpeedAlertsId  PredictedLabel  A1MSouthConfidence  A1MNorthConfidence  \
# 0       1.000000e+18             0.0            0.725928            0.274072
# 1       1.000000e+18             0.0            0.725928            0.274072
# 2       1.000000e+18             0.0            0.725928            0.274072
# 3       1.000000e+18             0.0            0.725928            0.274072
# 4       1.000000e+18             0.0            0.999982            0.000018
# ...              ...             ...                 ...                 ...
# 74256   1.000000e+18             1.0            0.194176            0.805798
# 74257   1.000000e+18             1.0            0.365679            0.634321
# 74258   1.000000e+18             1.0            0.254693            0.745298
# ...

# %%
 a = list([5] * 200) + list([543214] * 200) + list([321] * 10)
